# %%
import requests
import pandas as pd 
from bs4 import BeautifulSoup

# %%
name=[] #List to store name of the product
prices=[] #List to store price of the product
ratings=[] #List to store rating of the product
df=pd.DataFrame()

# %%
product_name = input("Product Name- ")
# Out:
# Product Name- laptops

# %%
url="https://www.flipkart.com/search?q=laptops&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"

# %%
page=requests.get(url)
html=page.content

# %%
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
data=response.text

# %%
data
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<link href="https://rukminim1.flixcart.com" rel="dns-prefetch" />\n\t<link href="https://img1a.flixcart.com" rel="dns-prefetch" />\n\t<link rel="stylesheet" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.21be2e.css" />\n\n\t<link rel="preload" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" as="image">\n\n\t<meta http-equiv="Content-type" content="text/html; charset=utf-8"/>\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\n\t<meta property="fb:page_id" content="102988293558"/>\n\t<meta property="fb:admins" content="658873552,624500995,100000233612389"/>\n\t<meta name="robots" content="noodp" />\n\n\t<link rel=\'shortcut icon\' href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" />\n\n\t<link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/>\n\n\t<meta property="og:type" content="website"/>\n\t<meta name="og_site_name" property="og:site_name" content="Flipkart.com"/>\n\t<!-- Appple Touch Icons -->\n\t<link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/>\n\t<link rel="apple-touch-icon" sizes="72x72" href="/apple-touch-icon-72x72.png"/>\n\t<link rel="apple-touch-icon" sizes="114x114" href="/apple-touch-icon-114x114.png"/>\n\t<link rel="apple-touch-icon" sizes="144x144" href="/apple-touch-icon-144x144.png"/>\n\t<link rel="apple-touch-icon" href="/apple-touch-icon-57x57.png"/>\n\n\t<!-- Twitter Meta Data -->\n\t<meta name=\'twitter:card\' content="app">\n\t<meta name="twitter:site" content="@flipkart">\n\t<meta name="twitter:creator" content="@flipkart">\n\t<meta name="twitter:title" content="Laptops - Buy Products Online at Best Price in India - All Categories | Flipkart.com">\n\t<meta name=\'twitter:description\' content="Shop for electronics, apparels & more using our Flipkart app Free shipping & COD.">\n\n\t<meta name=\'twitter:app:country\' content="in">\n\t<meta name="al:ios:app_name" content="Flipkart">\n\t<meta name="al:ios:app_store_id" content="742044692">\n\t<meta name="twitter:app:name:iphone" content="Flipkart">\n\t<meta name="twitter:app:id:iphone" content="742044692">\n\t<meta name="twitter:app:url:iphone" content="http://dl.flipkart.com/dl/home?">\n\t<meta name="twitter:app:name:ipad" content="Flipkart">\n\t<meta name="twitter:app:id:ipad" content="742044692">\n\t<meta name="twitter:app:url:ipad" content="http://dl.flipkart.com/dl/home?">\n\t<meta name="twitter:app:name:googleplay" content="Flipkart">\n\t<meta name="twitter:app:id:googleplay" content="com.flipkart.android">\n\t<meta name="twitter:app:url:googleplay" content="http://dl.flipkart.com/dl/home?">\n\t<style>\n\t\t#container {\n\t\t\theight: 100%;\n\t\t}\n\t</style>\n\n\t<script src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/js/runtime.06d597f8.js" defer crossorigin="anonymous"></script>\n\t<script src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/js/vendor.chunk.5029c9bf.js" defer crossorigin="anonymous"></script>\n\t<script src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/js/app_modules.chunk.04d72cb2.js" defer crossorigin="anonymous"></script>\n\t<script src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/js/app_common.chunk.f1bb769c.js" defer crossorigin="anonymous"></script>\n\t<script src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/js/app.chunk.3e18d6fd.js" defer crossorigin="anonymous"></script>\n\n\t\t<link rel="stylesheet" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/MultiWidgetBase.chunk.8d0706.css" />\n\t\t<link rel="stylesheet" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/Browse.chunk.4dadf6.css" />\n\n\t<title>Laptops - Buy Products Online at Best Price in India - All Categories | Flipkart.com</title>\n\t<meta name="og_title" property="og:title" content="Laptops - Buy Products Online at Best Price in India - All Categories | Flipkart.com"/>\n\n        <meta name="Keywords" content="Laptops"/>\n\n        <meta name="Description" cont ...

# %%
soup=BeautifulSoup(response.text,"html.parser")

# %%
main_box=soup.find_all("div",{"class":"_1UoZlX"})

# %%
len(main_box)
# Out:
# 24

# %%
box=main_box[0]

# %%
box
# Out:
# <div class="_1UoZlX"><a class="_31qSD5" href="/asus-vivobook-15-ryzen-5-quad-core-8-gb-1-tb-hdd-256-gb-ssd-windows-10-home-x512da-ej1298ts-thin-light-laptop/p/itma57ee403ae2e9?pid=COMFSKF9FR8MRF9H&amp;lid=LSTCOMFSKF9FR8MRF9HHT85CX&amp;marketplace=FLIPKART&amp;srno=s_1_1&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=4e9201a9-4881-48c7-9893-9786204a050b.COMFSKF9FR8MRF9H.SEARCH&amp;ssid=11rsmsldq80000001595841983627&amp;qH=c06ea84a1e3dc3c6" rel="noopener noreferrer" target="_blank"><div class="_3SQWE6"><div class="_1OCn9C"><div><div class="_3BTv9X" style="height:200px;width:200px"><img alt="Asus VivoBook 15 Ryzen 5 Quad Core - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home) X512DA-EJ1298TS Thin a..." class="_1Nyybr" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_9951d0.svg"/></div></div></div><div class="_2lesQu"><div class="_1O_CiZ"><span class="_1iHA1p"><div class="_2kFyHg"><label><input class="_3uUUD5" readonly="" type="checkbox"/><div class="_1p7h2j"></div></label></div></span><label class="_10TB-Q"><span>Add to Compare</span></label></div></div><div class="_3gDSOa _32A6AP"><div class="DsQ2eg"><svg class="_2oLiqr" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="_35Y7Yo" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></path></svg></div></div></div><div class="_1-2Iqu row"><div class="col col-7-12"><div class="_3wU53n">Asus VivoBook 15 Ryzen 5 Quad Core - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home) X512DA-EJ1298TS Thin a...</div><div class="niH0FQ"><span class="_2_KrJI" id="productRating_LSTCOMFSKF9FR8MRF9HHT85CX_COMFSKF9FR8MRF9H_"><div class="hGSR34">4.7<img class="_2lQ_WZ" src="..."/></div></span><span class="_38sUEc"><span><span>94 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 23 Reviews</span></span></span></div><div class="_3ULzGw"><ul class="vFw0gD"><li class="tVe95H">AMD Ryzen 5 Quad Core Processor</li><li class="tVe95H">8 GB DDR4 RAM</li><li class="tVe95H">64 bit Windows 10 Operating System</li><li class="tVe95H">1 TB HDD|256 GB SSD</li><li class="tVe95H">39.62 cm (15.6 inch) Display</li><li class="tVe95H">My Asus</li><li class="tVe95H">1 Year Onsite Warranty</li></ul></div></div><div class="col col-5-12 _2o7WAb"><div class="_6BWGkk"><div class="_1uv9Cb"><div class="_1vC4OE _2rQ-NK">₹47,990</div><div class="_3auQ3N _2GcJzG">₹<!-- -->49,151</div><div class="VGWI6T"><span>2% off</span></div></div></div><div class="_3n6o0t"><img height="21" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fa_8b4b59.png"/></div><div class="_2nE8_R"><div class="_3_G5Wj" style="color:#000000;font-size:14px;font-family:inherit;font-weight:normal">Upto </div><div class="_3_G5Wj" style="color:#000000;font-size:14px;font-family:inherit;font-weight:bold">₹8,400</div><div class="_3_G5Wj" style="color:#000000;font-size:14px;font-family:inherit;font-weight:normal"> Off on Exchange</div></div><div class="_2nE8_R"><div class="_3_G5Wj" style="color:#000000;font-size:14px;font-family:inherit;font-weight:normal">No Cost EMI</div></div></div></div></a></div>

# %%
title=box.find('div',{'class':'_3wU53n'}).text.strip()
price=box.find('div', {'class':'_1vC4OE _2rQ-NK'}).text.strip()
rating=box.find('div',{'class':'hGSR34'}).text.strip()

# %%
print(title,price,rating)
# Out:
# Asus VivoBook 15 Ryzen 5 Quad Core - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home) X512DA-EJ1298TS Thin a... ₹47,990 4.7

# %%
data_list = []
for box in main_box:
    temp_dict={}
    temp_dict ['TITLE'] = box.find('div',{'class':'_3wU53n'}).text.strip()
    temp_dict ['PRICE'] = box.find('div', {'class':'_1vC4OE _2rQ-NK'}).text.replace('₹','').strip()
    temp_dict ['RATING']= box.find('div', {'class':'hGSR34'}).text.strip()
    data_list.append(temp_dict)

# %%
temp_dict ['PRICE'] = box.find('div', {'class':'_1vC4OE _2rQ-NK'}).text.replace(',','').strip()

# %%
data_list
# Out:
# [{'TITLE': 'Asus VivoBook 15 Ryzen 5 Quad Core - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home) X512DA-EJ1298TS Thin a...',
#   'PRICE': '47,990',
#   'RATING': '4.7'},
#  {'TITLE': 'Asus VivoBook Gaming Core i5 8th Gen - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA Geforce G...',
#   'PRICE': '51,990',
#   'RATING': '4.5'},
#  {'TITLE': 'HP 14s Core i5 10th Gen - (8 GB/512 GB SSD/Windows 10 Home) 14s-cs3010TU Laptop',
#   'PRICE': '52,990',
#   'RATING': '4.8'},
#  {'TITLE': 'Asus X512FA Core i3 10th Gen - (4 GB/512 GB SSD/Windows 10 Home) X512FA-EJ372T Laptop',
#   'PRICE': '38,990',
#   'RATING': '4.4'},
#  {'TITLE': 'HP 14s Core i3 10th Gen - (4 GB/256 GB SSD/Windows 10 Home) 14s-cf3047TU Thin and Light Laptop',
#   'PRICE': '34,490',
#   'RATING': '3.5'},
#  {'TITLE': 'Lenovo Ideapad S340 Core i5 10th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home) 81VV ideapad S340 -1...',
#   'PRICE': '56,990',
#   'RATING': '4.5'},
#  {'TITLE': 'HP 15s Core i5 10th Gen - (8 GB/512 GB SSD/Windows 10 Home) 15s-du2078TU Thin and Light Laptop',
#   'PRICE': '52,990',
#   'RATING': '4.5'},
#  {'TITLE': 'Lenovo Ideapad 130 Core i3 7th Gen - (4 GB/1 TB HDD/Windows 10 Home) 130-15IKB Laptop',
#   'PRICE': '32,990',
#   'RATING': '4'},
#  {'TITLE': 'Asus VivoBook 14 Core i3 10th Gen - (4 GB/256 GB SSD/Windows 10 Home) X412FA-EK362T Thin and Light Lap...',
#   'PRICE': '37,990',
#   'RATING': '4.4'},
#  {'TITLE': 'Asus Core i5 10th Gen - (8 GB/512 GB SSD/Windows 10 Home/2 GB Graphics) X509JB-EJ592T Laptop',
#   'PRICE': '51,990',
#   'RATING': '4.5'},
#  {'TITLE': 'Asus Core i5 10th Gen - (8 GB/512 GB SSD/Windows 10 Home/2 GB Graphics) X509JB-EJ591T Laptop',
#   'PRICE': '51,990',
#   'RATING': '4.3'},
#  {'TITLE': 'Acer Swift 3 Core i5 8th Gen - (8 GB/512 GB SSD/Windows 10 Home/2 GB Graphics) SF314-55G Thin and Ligh...',
#   'PRICE': '52,990',
#   'RATING': '4.5'},
#  {'TITLE': 'Dell Inspiron 3000 APU Dual Core A9 - (4 GB/1 TB HDD/Windows 10 Home) 3595 Laptop',
#   'PRICE': '27,990',
#   'RATING': '2.3'},
#  {'TITLE': 'HP Pavilion Gaming Ryzen 5 Quad Core - (8 GB/1 TB HDD/Windows 10 Home/4 GB Graphics/NVIDIA Geforce GTX...',
#   'PRICE': '54,990',
#   'RATING': '4.3'},
#  {'TITLE': 'Lenovo Thinkpad Core i3 10th Gen - (4 GB/1 TB HDD/Windows 10) E14 Laptop',
#   'PRICE': '38,990',
#   'RATING': '4.1'},
#  {'TITLE': 'Asus VivoBook 14 Core i3 10th Gen - (4 GB/256 GB SSD/Windows 10 Home) X412FA-EK363T Thin and Light Lap...',
#   'PRICE': '36,990',
#   'RATING': '4.4'},
#  {'TITLE': 'HP Pavilion Gaming Ryzen 5 Quad Core - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA Geforce G...',
#   'PRICE': '59,999',
#   'RATING': '4.8'},
#  {'TITLE': 'Asus VivoBook S Series Core i5 8th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home) S430FA-EB039T Thin...',
#   'PRICE': '52,990',
#   'RATING': '4.5'},
#  {'TITLE': 'Lenovo Thinkpad E14 Core i5 10th Gen - (8 GB/1 TB HDD/128 GB SSD/Windows 10 Home) E14 Thin and Light L...',
#   'PRICE': '59,990',
#   'RATING': '4.8'},
#  {'TITLE': 'Dell G3 Core i7 9th Gen - (8 GB/1 TB HDD/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA Geforce GTX 1...',
#   'PRICE': '84,990',
#   'RATING': '4.3'},
#  {'TITLE': 'Asus VivoBook 14 Core i5 10th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home/2 GB Graphics) X412FJ-EK...',
#   'PRICE': '59,990',
#   'RATING': '4.5'},
#  {'TITLE': 'Asus ZenBook Core i5 8th Gen - (8 GB/256 GB SSD/Windows 10 Home) UX430UA-GV573T Thin and Light Laptop',
#   'PRICE': '47,990',
#   'RATING': '4.1'},
#  {'TITLE': 'Acer Swift 3 Core i3 8th Gen - (4 GB/256 GB SSD/Windows 10 Home) SF313-51-30EP Thin and Light Laptop',
#   'PRICE': '45,990',
#   'RATING': '4.5'},
#  {'TITLE': 'HP Pavilion x360 14 Core i3 10th Gen - (4 GB/256 GB SSD/Windows 10 Home) 14-dh1007TU 2 in 1 Laptop',
#   'PRICE': '50,990',
#   'RATING': '4.2'}]

# %%
df.dtypes
# Out:
# TITLE      object
# PRICE      object
# RATING    float64
# dtype: object

# %%
df['RATING'] = df['RATING'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6e595f9ff1c0> in <module>
# ----> 1 df['RATING'] = df['RATING'].astype(float)
#
# NameError: name 'df' is not defined

# %%
df=pd.DataFrame(data_list)

# %%
df
# Out:
#                                                 TITLE   PRICE RATING
# 0   Asus VivoBook 15 Ryzen 5 Quad Core - (8 GB/1 T...  47,990    4.7
# 1   Asus VivoBook Gaming Core i5 8th Gen - (8 GB/5...  51,990    4.5
# 2   HP 14s Core i5 10th Gen - (8 GB/512 GB SSD/Win...  52,990    4.8
# 3   Asus X512FA Core i3 10th Gen - (4 GB/512 GB SS...  38,990    4.4
# 4   HP 14s Core i3 10th Gen - (4 GB/256 GB SSD/Win...  34,490    3.5
# 5   Lenovo Ideapad S340 Core i5 10th Gen - (8 GB/1...  56,990    4.5
# 6   HP 15s Core i5 10th Gen - (8 GB/512 GB SSD/Win...